# %% [markdown]
# # Build Up My Own Recommend Playlist from Scratch

# %% [markdown]
# Collaborative Filtering is usually the first type of method for recommender system. It has two approachs, the first one is user-user based model, which use the similiarity between user to recommend new items, another one is item-item based model. Instead of using the similarity between users, it uses that between items to recommend new items.
#
# Here, we are going to go beyond collaborative filtering and introduce latent factor model in the application of recommender system. In this article, we are going to use [Million Song Dataset](https://labrosa.ee.columbia.edu/millionsong/). It contains users and song data. The main motivation behind is that when we using music streaming service like Spotify, kkbox, and youtube, the recommended songs often catch my eye. Take Spotify for example, there is a feature called *Discover Weekly*, which automatically generate a recommended playlist weekly. Very often, I enjoyed listening to the recommended songs. Therefore, I think it will be a great idea if I can build up a recommend playlist or songs using different methods, and to see what the result will be.
#
# Here are the steps that I take for this experiment:
# * Take [Million Song Dataset](https://labrosa.ee.columbia.edu/millionsong/)
# * Use user-user based collaborative filtering to build up a recommended playlist
# * Use item-item based collaborative filtering to build up a recommended playlist
# * Use Latent Factor Model to build up a recommended playlist
# * Measure the performance using Root Mean Square Error(RMSE)
# * Compare the result of different approachs

# %% [markdown]
# For collaborative filtering, we follow the same step as the [previous notebook for recommending movies](https://github.com/johnnychiuchiu/Machine-Learning/blob/master/RecommenderSystem/collaborative_filtering.ipynb).
# Firstly, in order to calculate the similarity, we need to get a utility matrix using the song dataframe. For illustration purpose, I also manually append three rows into the utility matrix. Each row represent a person with some specific music taste.
#
# We use two method to compare the measure the result of different approachs. The first approach is calculate the Mean Square Error. Since both collaborative filtering and latent factor model need all the dataset to calcualte the predicted result. The way we generate train and test different from the way we usually use, that is randomly select some row to be test.
#
# In the song data, we randomly take 3 listen_count of each user out and place it in the test dataset. Then we use only train dataset to predict the recommended playlist. After have the predicted score for all the songs, we then compare the nonzero values in test data set with the corresponding value in the train dataset and calcualte the MSE of it. Also, I have make sure each user has at least listened to 5 different songs in the song data.

# %% [markdown]
# ---

# %% [markdown]
# ## Implementing Collaborative Filtering to build up Recommeded Playlist

# %%
# %matplotlib inline

import pandas as pd
from sklearn.cross_validation import train_test_split
import numpy as np
import os
from sklearn.metrics import mean_squared_error
# Out:
# /Users/johnnychiu/Library/Python/3.6/lib/python/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
song_df = pd.read_pickle('_data/song.pkl')

# %%
song_df[song_df.artist_name=='John Mayer'].title.unique()
# Out:
# array(['Clarity', 'Love Song For No One', '83', 'Neon', 'Come Back To Bed',
#        'City Love', 'Heartbreak Warfare', 'Half Of My Heart',
#        'Waiting On The World To Change', 'Good Love Is On The Way',
#        'Why Georgia', 'All We Ever Do Is Say Goodbye',
#        'Slow Dancing In A Burning Room', 'Crossroads', 'Perfectly Lonely',
#        'Bold As Love', 'Back To You', 'Gravity', 'The Heart Of Life',
#        'Friends_ Lovers Or Nothing', "I'm Gonna Find Another You",
#        'Do You Know Me', 'Great Indoors', 'War Of My Life',
#        'Who Did You Think I Was', "I Don't Need No Doctor",
#        "St. Patrick's Day", "Free Fallin'"], dtype=object)

# %%
[print(i) for i in song_df.artist_name.unique()]
# Out:
# Jack Johnson
# Paco De Lucia
# Kanye West
# Foo Fighters
# Goldfinger
# Emilie Simon
# Sam Paglia
# Sheila Walsh
# T.I. & DJ Drama
# Strike Anywhere
# Ronnie Foster
# Senses Fail
# Parkway Drive
# Musiq / DJ Aktive / Carol Riddick
# Toni Braxton
# Blackfoot
# Musiq Soulchild
# 1001
# Anya Marina
# Jamie T
# Scott Walker
# Medeski_ Martin & Wood
# John Travolta / Olivia Newton-John
# Trisha Yearwood
# The Lonely Island / Jack Black
# Algora
# Sangre Azul
# Feargal Sharkey
# Jack White & Alicia Keys
# Scott Krippayne
# Matthew Dear
# Ray Charles
# Lupe Fiasco feat. Nikki Jean
# Leo Garcia
# Cute Is What We Aim For
# Mama's Jasje
# Bill Conti
# The Thrills
# Ray Barretto
# Alejandro Fernandez
# Aphex Twin
# Tone Loc
# James Ingram;Linda Ronstadt
# The Jesus And Mary Chain
# The Lemonheads
# Gramophonedzie
# The Bobby Fuller Four
# The Chills
# Grace Potter and the Nocturnals
# La Ley
# Timbaland / Fall Out Boy
# The Trews
# Ricky Martin Feat. La Mari de "Chambao
# Airscape
# Rhonda Vincent
# Cary Brothers
# Cinematic Orchestra
# Opeth
# Blacks ft. P Money
# Il Divo
# Georgia Satellites
# Captain & Tennille
# Akron/Family
# Snoop Dogg featuring Kid Cudi
# Umphrey's McGee
# Left Lane Cruiser
# Ricardo Montaner
# Franco De Vita
# Aril Brikha
# Spin Doctors
# Heavy D & The Boyz / Aaron Hall
# Dobie Gray
# The Black Ghosts
# Mike Nero
# Di-rect
# M.O.P.
# The Cool Kids
# Jay-Z featuring Memphis Bleek
# Eden's Bridge
# Black Rob
# Be Bop Deluxe
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ...]

# %%
len(song_df.user_id.unique())
# Out:
# 76353

# %%
len(song_df.song_id.unique())
# Out:
# 10000

# %%
def compute_mse(y_true, y_pred):
    """ignore zero terms prior to comparing the mse"""
    mask = np.nonzero(y_true)
    mse = mean_squared_error(y_true[mask], y_pred[mask])
    return mse

def create_train_test(ratings):
    """
    split into training and test sets,
    remove 3 ratings from each user
    and assign them to the test set
    """
    test = np.zeros(ratings.shape)
    train = ratings.copy()
    for user in range(ratings.shape[0]):
        test_index = np.random.choice(
            np.flatnonzero(ratings[user]), size=3, replace=False)

        train[user, test_index] = 0.0
        test[user, test_index] = ratings[user, test_index]

    # assert that training and testing set are truly disjoint
    assert np.all(train * test == 0)
    return (train, test)

# %%
class collaborativeFiltering():
    def __init__(self):
        pass

    def readSongData(self, top):
        """
        Read song data from targeted url
        """
        if 'song.pkl' in os.listdir('_data/'):
            song_df = pd.read_pickle('_data/song.pkl')
        else:
            # Read userid-songid-listen_count triplets
            # This step might take time to download data from external sources
            triplets_file = 'https://static.turi.com/datasets/millionsong/10000.txt'
            songs_metadata_file = 'https://static.turi.com/datasets/millionsong/song_data.csv'

            song_df_1 = pd.read_table(triplets_file, header=None)
            song_df_1.columns = ['user_id', 'song_id', 'listen_count']

            # Read song  metadata
            song_df_2 = pd.read_csv(songs_metadata_file)

            # Merge the two dataframes above to create input dataframe for recommender systems
            song_df = pd.merge(song_df_1, song_df_2.drop_duplicates(['song_id']), on="song_id", how="left")



            # Merge song title and artist_name columns to make a merged column
            song_df['song'] = song_df['title'].map(str) + " - " + song_df['artist_name']

            n_users = song_df.user_id.unique().shape[0]
            n_items = song_df.song_id.unique().shape[0]
            print(str(n_users) + ' users')
            print(str(n_items) + ' items')

            song_df.to_pickle('_data/song.pkl')

        # keep top_n rows of the data
        song_df = song_df.head(top)

        song_df = self.drop_freq_low(song_df)

        return(song_df)

    def drop_freq_low(self, song_df):
        freq_df = song_df.groupby(['user_id']).agg({'song_id': 'count'}).reset_index(level=['user_id'])
        below_userid = freq_df[freq_df.song_id <= 5]['user_id']
        new_song_df = song_df[~song_df.user_id.isin(below_userid)]

        return(new_song_df)

    def utilityMatrix(self, song_df):
        """
        Transform dataframe into utility matrix, return both dataframe and matrix format
        :param song_df: a dataframe that contains user_id, song_id, and listen_count
        :return: dataframe, matrix
        """
        song_reshape = song_df.pivot(index='user_id', columns='song_id', values='listen_count')
        song_reshape = song_reshape.fillna(0)
        ratings = song_reshape.as_matrix()
        return(song_reshape, ratings)

    def fast_similarity(self, ratings, kind='user', epsilon=1e-9):
        """
        Calculate the similarity of the rating matrix
        :param ratings: utility matrix
        :param kind: user-user sim or item-item sim
        :param epsilon: small number for handling dived-by-zero errors
        :return: correlation matrix
        """

        if kind == 'user':
            sim = ratings.dot(ratings.T) + epsilon
        elif kind == 'item':
            sim = ratings.T.dot(ratings) + epsilon
        norms = np.array([np.sqrt(np.diagonal(sim))])
        return (sim / norms / norms.T)

    def predict_fast_simple(self, ratings, kind='user'):
        """
        Calculate the predicted score of every song for every user.
        :param ratings: utility matrix
        :param kind: user-user sim or item-item sim
        :return: matrix contains the predicted scores
        """

        similarity = self.fast_similarity(ratings, kind)

        if kind == 'user':
            return similarity.dot(ratings) / np.array([np.abs(similarity).sum(axis=1)]).T
        elif kind == 'item':
            return ratings.dot(similarity) / np.array([np.abs(similarity).sum(axis=1)])

    def get_overall_recommend(self, ratings, song_reshape, user_prediction, top_n=10):
        """
        get the top_n predicted result of every user. Notice that the recommended item should be the song that the user
         haven't listened before.
        :param ratings: utility matrix
        :param song_reshape: utility matrix in dataframe format
        :param user_prediction: matrix with predicted score
        :param top_n: the number of recommended song
        :return: a dict contains recommended songs for every user_id
        """
        result = dict({})
        for i, row in enumerate(ratings):
            user_id = song_reshape.index[i]
            result[user_id] = {}
            zero_item_list = np.where(row == 0)[0]
            prob_list = user_prediction[i][np.where(row == 0)[0]]
            song_id_list = np.array(song_reshape.columns)[zero_item_list]
            result[user_id]['recommend'] = sorted(zip(song_id_list, prob_list), key=lambda item: item[1], reverse=True)[
                                           0:top_n]

        return (result)

    def get_user_recommend(self, user_id, overall_recommend, song_df):
        """
        Get the recommended songs for a particular user using the song information from the song_df
        :param user_id:
        :param overall_recommend:
        :return:
        """
        user_score = pd.DataFrame(overall_recommend[user_id]['recommend']).rename(columns={0: 'song_id', 1: 'score'})
        user_recommend = pd.merge(user_score,
                                  song_df[['song_id', 'title', 'release', 'artist_name', 'song']].drop_duplicates(),
                                  on='song_id', how='left')
        return (user_recommend)

    def createNewObs(self, artistName, song_reshape, index_name):
        """
        Append a new row with userId 0 that is interested in some specific artists
        :param artistName: a list of artist names
        :return: dataframe, matrix
        """
        interest = []
        for i in song_reshape.columns:
            if i in song_df[song_df.artist_name.isin(artistName)]['song_id'].unique():
                interest.append(10)
            else:
                interest.append(0)

        print(pd.Series(interest).value_counts())

        newobs = pd.DataFrame([interest],
                              columns=song_reshape.columns)
        newobs.index = [index_name]

        new_song_reshape = pd.concat([song_reshape, newobs])
        new_ratings = new_song_reshape.as_matrix()
        return (new_song_reshape, new_ratings)

# %% [markdown]
# ## Take Million Song Dataset

# %% [markdown]
# We only keep the first 50000 rows for this notebook. Otherwise it will take too long to execute it. As following, we can see that there are around **17k** users and **93k** different songs out of the first 50k rows.

# %%
cf = collaborativeFiltering()
song_df = cf.readSongData(100000)

# %%
song_df.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title                        release    artist_name  year  \
# 0         The Cove             Thicker Than Water   Jack Johnson     0
# 1  Entre Dos Aguas            Flamenco Para Niños  Paco De Lucia  1976
# 2         Stronger                     Graduation     Kanye West  2007
# 3   Constellations              In Between Dreams   Jack Johnson  2005
# 4     Learn To Fly  There Is Nothing Left To Lose   Foo Fighters  1999
#
#                               song
# 0          The Cove - Jack Johnson
# 1  Entre Dos Aguas - Paco De Lucia
# 2            Stronger - Kanye West
# 3    Constellations - Jack Johnson
# 4      Learn To Fly - Foo Fighters

# %%
artist_df= song_df.groupby(['artist_name']).agg({'song_id':'count'}).reset_index(level=['artist_name']).sort_values(by='song_id',ascending=False).head(100)

# %%
n_users = song_df.user_id.unique().shape[0]
n_items = song_df.song_id.unique().shape[0]
print(str(n_users) + ' users')
print(str(n_items) + ' songs')
# Out:
# 3464 users
# 9930 songs

# %% [markdown]
# • **Get the utility matrix**

# %%
song_reshape, ratings = cf.utilityMatrix(song_df)

# %% [markdown]
# • **Append new rows to simulate a users who love different kinds of musicians**

# %%
song_reshape, ratings = cf.createNewObs(['Beyoncé', 'Katy Perry', 'Alicia Keys'], song_reshape, 'GirlFan')
song_reshape, ratings = cf.createNewObs(['Metallica', 'Guns N\' Roses', 'Linkin Park', 'Red Hot Chili Peppers'],
                                        song_reshape, 'HeavyFan')
song_reshape, ratings = cf.createNewObs(['Daft Punk','John Mayer','Hot Chip','Coldplay'],
                                        song_reshape, 'Johnny')
# Out:
# 0     9876
# 10      54
# dtype: int64
# 0     9801
# 10     129
# dtype: int64
# 0     9747
# 10     183
# dtype: int64

# %% [markdown]
# • **Create train test dataset**

# %%
train, test = create_train_test(ratings)

# %%
song_reshape.shape
# Out:
# (3467, 9930)

# %% [markdown]
# ## Calculate user-user collaborative filtering

# %%
user_prediction = cf.predict_fast_simple(train, kind='user')
user_overall_recommend = cf.get_overall_recommend(train, song_reshape, user_prediction, top_n=10)
user_recommend_girl = cf.get_user_recommend('GirlFan', user_overall_recommend, song_df)
user_recommend_heavy = cf.get_user_recommend('HeavyFan', user_overall_recommend, song_df)
user_recommend_johnny = cf.get_user_recommend('Johnny', user_overall_recommend, song_df)

# %% [markdown]
# ## Calculate item-item collaborative filtering

# %%
item_prediction = cf.predict_fast_simple(train, kind='item')
item_overall_recommend = cf.get_overall_recommend(train, song_reshape, item_prediction, top_n=10)
item_recommend_girl = cf.get_user_recommend('GirlFan', item_overall_recommend, song_df)
item_recommend_heavy = cf.get_user_recommend('HeavyFan', item_overall_recommend, song_df)
item_recommend_johnny = cf.get_user_recommend('Johnny', item_overall_recommend, song_df)

# %% [markdown]
# ---

# %% [markdown]
# The main idea behind Latent Factor Model is that we can transform our utility matrix into the multiple of two lower rank matrix. For example, if we have 5 users and 10 songs, then our utility matrix is 5 * 10. We can transform the matrix in to two matrixs, say 5 x 3 (say Q) and 3 x 10 (say P). Each user can be represented by a vector in 3 dimension, and each song can als obe represented by a vector in 3 dimension. The meaning of each dimension for Q can be, for example, do the user like jazz related music; each dimension for P can be, for example, is it a jazz song. The picture copied from google search result visualize it more clearly:
#
# ![](_pic/latentfactor.png)

# %% [markdown]
# In order to get all the values in the Q and P, we need some optimization method to help us. The optimization method suggested by the winner of Netflix is called **Alternating Least Squares with Weighted Regularization (ALS-WR)**.
#
# Our cost function is as follows:
#
# $$ \begin{align} L &= \sum\limits_{u,i \in S}( r_{ui} - \textbf{x}_{u} \textbf{y}_{i}^{T} )^{2} + \lambda \big( \sum\limits_{u} \left\Vert \textbf{x}_{u} \right\Vert^{2} + \sum\limits_{i} \left\Vert \textbf{y}_{i} \right\Vert^{2} \big) \end{align} $$

# %% [markdown]
# We will try to minimize the loss function to get our optimal $x_u$ and $y_i$ vectors. The main idea behind ALS-WR method is that we try to get the optimal Q and P matrix by holding one vector to be fixed at a time. We alternate back and forth until the value of Q and P converges. The reason why we don't optimize both vector at the same time is that it is hard to get optimal vectors at the same time. By holding one vector to be fixed and optimize another vector alternately, we can find the optimal Q and P more efficiently.
#
# For a detailed explaination on how to
# please check [Ethen's Alternating Least Squares with Weighted Regularization (ALS-WR) from scratch](http://nbviewer.jupyter.org/github/ethen8181/machine-learning/blob/master/recsys/1_ALSWR.ipynb).

# %% [markdown]
# ## Recommend using Latent Factor Model

# %%
class ExplicitMF:
    """
    This function is directly taken from Ethen's github (http://nbviewer.jupyter.org/github/ethen8181/machine-learning/blob/master/recsys/1_ALSWR.ipynb)
    Train a matrix factorization model using Alternating Least Squares
    to predict empty entries in a matrix

    Parameters
    ----------
    n_iters : int
        number of iterations to train the algorithm

    n_factors : int
        number of latent factors to use in matrix
        factorization model, some machine-learning libraries
        denote this as rank

    reg : float
        regularization term for item/user latent factors,
        since lambda is a keyword in python we use reg instead
    """

    def __init__(self, n_iters, n_factors, reg):
        self.reg = reg
        self.n_iters = n_iters
        self.n_factors = n_factors

    def fit(self, train):#, test
        """
        pass in training and testing at the same time to record
        model convergence, assuming both dataset is in the form
        of User x Item matrix with cells as ratings
        """
        self.n_user, self.n_item = train.shape
        self.user_factors = np.random.random((self.n_user, self.n_factors))
        self.item_factors = np.random.random((self.n_item, self.n_factors))

        # record the training and testing mse for every iteration
        # to show convergence later (usually, not worth it for production)
        # self.test_mse_record = []
        # self.train_mse_record = []
        for _ in range(self.n_iters):
            self.user_factors = self._als_step(train, self.user_factors, self.item_factors)
            self.item_factors = self._als_step(train.T, self.item_factors, self.user_factors)
            predictions = self.predict()
            # test_mse = self.compute_mse(test, predictions)
            # train_mse = self.compute_mse(train, predictions)
            # self.test_mse_record.append(test_mse)
            # self.train_mse_record.append(train_mse)

        return self

    def _als_step(self, ratings, solve_vecs, fixed_vecs):
        """
        when updating the user matrix,
        the item matrix is the fixed vector and vice versa
        """
        A = fixed_vecs.T.dot(fixed_vecs) + np.eye(self.n_factors) * self.reg
        b = ratings.dot(fixed_vecs)
        A_inv = np.linalg.inv(A)
        solve_vecs = b.dot(A_inv)
        return solve_vecs

    def predict(self):
        """predict ratings for every user and item"""
        pred = self.user_factors.dot(self.item_factors.T)
        return pred

# %% [markdown]
# • **Fit using Alternating Least Square Method**

# %%
als = ExplicitMF(n_iters=200, n_factors=10, reg=0.01)
als.fit(train)

# %%
latent_prediction = als.predict()
latent_overall_recommend = cf.get_overall_recommend(train, song_reshape, latent_prediction, top_n=10)
latent_recommend_girl = cf.get_user_recommend('GirlFan', latent_overall_recommend, song_df)
latent_recommend_heavy = cf.get_user_recommend('HeavyFan', latent_overall_recommend, song_df)
latent_recommend_johnny = cf.get_user_recommend('Johnny', latent_overall_recommend, song_df)

# %% [markdown]
# ## Measure the performance using Root Mean Square Error(RMSE)

# %%
user_mse = compute_mse(test, user_prediction)
item_mse = compute_mse(test, item_prediction)
latent_mse = compute_mse(test, latent_prediction)

print("MSE for user-user approach: "+str(user_mse))
print("MSE for item-item approach: "+str(item_mse))
print("MSE for latent factor model: "+str(latent_mse))
# Out:
# MSE for user-user approach: 62.0203236977
# MSE for item-item approach: 62.9194512059
# MSE for latent factor model: 62.3739101416

# %% [markdown]
# We can see that even though latent factor model is somewhat a more advanced model, the MSE not the lowerest for some reason. It is something that I should keep in mind.

# %% [markdown]
# ## Compare the result of different approachs

# %% [markdown]
# ### > Recommend Playlist for someone who is a big fan of *Beyoncé*, *Katy Perry* and *Alicia Keys*

# %% [markdown]
# • **User-user approach**

# %%
user_recommend_girl
# Out:
#               song_id     score  \
# 0  SOFRQTD12A81C233C0  1.181721
# 1  SOAWJSH12A8C13AE09  0.698028
# 2  SOBONKR12A58A7A7E0  0.545459
# 3  SOCNIFM12A8C13D73B  0.507603
# 4  SONYKOW12AB01849C9  0.507429
# 5  SOFKABN12A8AE476C6  0.431391
# 6  SOAXGDH12A8C13F8A1  0.427585
# 7  SODJWHY12A8C142CCE  0.426170
# 8  SOPTLQL12AB018D56F  0.422424
# 9  SOAUWYT12A81C206F1  0.407228
#
#                                                title  \
# 0                                      Sehr kosmisch
# 1                                              Diary
# 2                                     You're The One
# 3                                        Ona Kasuita
# 4                                            Secrets
# 5                                         Just Dance
# 6                     Dog Days Are Over (Radio Edit)
# 7                                   Hey_ Soul Sister
# 8  Billionaire [feat. Bruno Mars]  (Explicit Albu...
# 9                                               Undo
#
#                             release  \
# 0                Musik von Harmonia
# 1          The Diary Of Alicia Keys
# 2                If There Was A Way
# 3         Mirando el mundo al revés
# 4                         Waking Up
# 5                        Just Dance
# 6  Now That's What I Call Music! 75
# 7            Save Me_ San Francisco
# 8    Billionaire [feat. Bruno Mars]
# 9                   Vespertine Live
#
#                                          artist_name  \
# 0                                           Harmonia
# 1  Alicia Keys featuring Tony! Toni! Toné! and Je...
# 2                                      Dwight Yoakam
# 3                                         Che Sudaka
# 4                                        OneRepublic
# 5                          Lady GaGa / Colby O'Donis
# 6                             Florence + The Machine
# 7                                              Train
# 8                                       Travie McCoy
# 9                                              Björk
#
#                                                 song
# 0                           Sehr kosmisch - Harmonia
# 1  Diary - Alicia Keys featuring Tony! Toni! Toné...
# 2                     You're The One - Dwight Yoakam
# 3                           Ona Kasuita - Che Sudaka
# 4                              Secrets - OneRepublic
# 5             Just Dance - Lady GaGa / Colby O'Donis
# 6  Dog Days Are Over (Radio Edit) - Florence + Th...
# 7                           Hey_ Soul Sister - Train
# 8  Billionaire [feat. Bruno Mars]  (Explicit Albu...
# 9                                       Undo - Björk

# %% [markdown]
# • **Item-item approach**

# %%
item_recommend_girl
# Out:
#               song_id     score                 title  \
# 0  SOUWBLM12A8C1353D7  1.700255              EMOTIONS
# 1  SOEVGOY12AB0181053  1.691904           Be With You
# 2  SOTYJZR12A6D4F6A3E  1.431639             Crossfire
# 3  SOCVKOK12AB0184D95  1.427024      You Make It Real
# 4  SOPZFDD12A8C13AE12  1.374971              A Prayer
# 5  SOTJTUX12AB018247F  1.367438  Keep You Much Longer
# 6  SOOXYLM12AB018472B  1.298002               Mr. Man
# 7  SOPKFQB12A67ADBAD6  1.283676      Teach U a Lesson
# 8  SOCNIFM12A8C13D73B  1.267186           Ona Kasuita
# 9  SOGKEGN12AB0185355  1.240405       I Want You Back
#
#                          release               artist_name  \
# 0                    The Remixes              Mariah Carey
# 1                        Freedom                      Akon
# 2                      23 Skidoo                 23 Skidoo
# 3                Essential Songs            James Morrison
# 4                    Red Balloon     East Blues Experience
# 5                        Freedom                      Akon
# 6               Songs In A Minor  Alicia Keys;Jimmy Cozier
# 7  The Evolution of Robin Thicke              Robin Thicke
# 8      Mirando el mundo al revés                Che Sudaka
# 9          Sweet Children O'Mine             Shione Yukawa
#
#                                  song
# 0             EMOTIONS - Mariah Carey
# 1                  Be With You - Akon
# 2               Crossfire - 23 Skidoo
# 3   You Make It Real - James Morrison
# 4    A Prayer - East Blues Experience
# 5         Keep You Much Longer - Akon
# 6  Mr. Man - Alicia Keys;Jimmy Cozier
# 7     Teach U a Lesson - Robin Thicke
# 8            Ona Kasuita - Che Sudaka
# 9     I Want You Back - Shione Yukawa

# %% [markdown]
# • **Latent Factor Model**

# %%
latent_recommend_girl
# Out:
#               song_id     score  \
# 0  SOHTKMO12AB01843B0  0.848369
# 1  SOAUWYT12A81C206F1  0.317627
# 2  SOUNZHU12A8AE47481  0.265404
# 3  SOWMDQL12A8C13FB54  0.223310
# 4  SOXWYZP12AF72A42A6  0.208454
# 5  SOZWBVE12AAF3B515C  0.206599
# 6  SOSXLTC12AF72A7F54  0.149426
# 7  SOBONKR12A58A7A7E0  0.134135
# 8  SOAXGDH12A8C13F8A1  0.120990
# 9  SODNXDD12AB018331A  0.116869
#
#                                                title  \
# 0  Catch You Baby (Steve Pitron & Max Sanna Radio...
# 1                                               Undo
# 2                                I CAN'T GET STARTED
# 3                                        What I Want
# 4                                        Cosmic Love
# 5                           Golden Mummy Golden Bird
# 6                                            Revelry
# 7                                     You're The One
# 8                     Dog Days Are Over (Radio Edit)
# 9                                          September
#
#                             release               artist_name  \
# 0                    Catch You Baby             Lonnie Gordon
# 1                   Vespertine Live                     Björk
# 2                     It's The Time                Ron Carter
# 3                          Daughtry  Daughtry featuring Slash
# 4                             Lungs    Florence + The Machine
# 5                  Desperate Living            Horse The Band
# 6                 Only By The Night             Kings Of Leon
# 7                If There Was A Way             Dwight Yoakam
# 8  Now That's What I Call Music! 75    Florence + The Machine
# 9                   Leave This Town                  Daughtry
#
#                                                 song
# 0  Catch You Baby (Steve Pitron & Max Sanna Radio...
# 1                                       Undo - Björk
# 2                   I CAN'T GET STARTED - Ron Carter
# 3             What I Want - Daughtry featuring Slash
# 4               Cosmic Love - Florence + The Machine
# 5          Golden Mummy Golden Bird - Horse The Band
# 6                            Revelry - Kings Of Leon
# 7                     You're The One - Dwight Yoakam
# 8  Dog Days Are Over (Radio Edit) - Florence + Th...
# 9                               September - Daughtry

# %% [markdown]
# ### > Recommend Playlist for someone who is a big fan of  *Metallica*, *Guns N' Roses*, *Linkin Park*  and *Red Hot Chili Peppers*

# %%
user_recommend_heavy
# Out:
#               song_id     score  \
# 0  SOHNRJO12A8AE44A2B  0.699864
# 1  SOBONKR12A58A7A7E0  0.494431
# 2  SOFRQTD12A81C233C0  0.472206
# 3  SOAUWYT12A81C206F1  0.422251
# 4  SOEGIYH12A6D4FC0E3  0.419705
# 5  SOLRGNF12AB0187CF4  0.298821
# 6  SOEKZAZ12A8C134536  0.283362
# 7  SOHHALP12A6D4FB6A8  0.273234
# 8  SOSXLTC12AF72A7F54  0.268378
# 9  SONYKOW12AB01849C9  0.264684
#
#                                                title  \
# 0                            Duality (Album Version)
# 1                                     You're The One
# 2                                      Sehr kosmisch
# 3                                               Undo
# 4  Horn Concerto No. 4 in E flat K495: II. Romanc...
# 5                                     Sample Track 2
# 6                                      No Government
# 7                                           Patience
# 8                                            Revelry
# 9                                            Secrets
#
#                            release  \
# 0     Vol. 3 The Subliminal Verses
# 1               If There Was A Way
# 2               Musik von Harmonia
# 3                  Vespertine Live
# 4  Mozart - Eine kleine Nachtmusik
# 5           Dance & Hip Hop Breaks
# 6                    No Government
# 7                      G N' R Lies
# 8                Only By The Night
# 9                        Waking Up
#
#                                          artist_name  \
# 0                                           Slipknot
# 1                                      Dwight Yoakam
# 2                                           Harmonia
# 3                                              Björk
# 4  Barry Tuckwell/Academy of St Martin-in-the-Fie...
# 5                                       Simon Harris
# 6                                          Nicolette
# 7                                      Guns N' Roses
# 8                                      Kings Of Leon
# 9                                        OneRepublic
#
#                                                 song
# 0                 Duality (Album Version) - Slipknot
# 1                     You're The One - Dwight Yoakam
# 2                           Sehr kosmisch - Harmonia
# 3                                       Undo - Björk
# 4  Horn Concerto No. 4 in E flat K495: II. Romanc...
# 5                      Sample Track 2 - Simon Harris
# 6                          No Government - Nicolette
# 7                           Patience - Guns N' Roses
# 8                            Revelry - Kings Of Leon
# 9                              Secrets - OneRepublic

# %%
item_recommend_heavy
# Out:
#               song_id     score                                 title  \
# 0  SOKNDKQ12A58A795CC  4.975385  Boom (2006 Remastered Album Version)
# 1  SOQGYQP12A8C1322D9  2.690343                            Down Rodeo
# 2  SOEKZAZ12A8C134536  2.524277                         No Government
# 3  SOXQBCW12AB018704A  2.244806                      Own Little World
# 4  SOMRAUN12A6D4F5224  2.207283             Departure (Album Version)
# 5  SONYBWB12A8C137FB7  2.176773    The Robots (2009 Digital Remaster)
# 6  SOHVHQE12A8C13AD3A  2.153587                                 Carol
# 7  SOCRIYW12A8C143467  2.105580                         Ella Elle L A
# 8  SOHNRJO12A8AE44A2B  2.022071               Duality (Album Version)
# 9  SOVDMUW12A8AE45BC1  1.945088           Skin Ticket (Album Version)
#
#                               release               artist_name  \
# 0  Greatest Hits [The Atlantic Years]                    P.O.D.
# 1                         Evil Empire  Rage Against The Machine
# 2                       No Government                 Nicolette
# 3                            ROUNDERS               Celldweller
# 4                          Ascendancy                   Trivium
# 5     The Mix (2009 Digital Remaster)                 Kraftwerk
# 6                         Vida Sonora        Spook And The Guay
# 7                                Free                 Kate Ryan
# 8        Vol. 3 The Subliminal Verses                  Slipknot
# 9                                Iowa                  Slipknot
#
#                                              song
# 0   Boom (2006 Remastered Album Version) - P.O.D.
# 1           Down Rodeo - Rage Against The Machine
# 2                       No Government - Nicolette
# 3                  Own Little World - Celldweller
# 4             Departure (Album Version) - Trivium
# 5  The Robots (2009 Digital Remaster) - Kraftwerk
# 6                      Carol - Spook And The Guay
# 7                       Ella Elle L A - Kate Ryan
# 8              Duality (Album Version) - Slipknot
# 9          Skin Ticket (Album Version) - Slipknot

# %%
latent_recommend_heavy
# Out:
#               song_id     score  \
# 0  SOHTKMO12AB01843B0  0.792534
# 1  SOBONKR12A58A7A7E0  0.640622
# 2  SOAUWYT12A81C206F1  0.533778
# 3  SOSXLTC12AF72A7F54  0.408930
# 4  SOUNZHU12A8AE47481  0.253766
# 5  SOWMDQL12A8C13FB54  0.203165
# 6  SOEGIYH12A6D4FC0E3  0.198884
# 7  SOZWBVE12AAF3B515C  0.152189
# 8  SOXWYZP12AF72A42A6  0.146668
# 9  SOFRQTD12A81C233C0  0.146006
#
#                                                title  \
# 0  Catch You Baby (Steve Pitron & Max Sanna Radio...
# 1                                     You're The One
# 2                                               Undo
# 3                                            Revelry
# 4                                I CAN'T GET STARTED
# 5                                        What I Want
# 6  Horn Concerto No. 4 in E flat K495: II. Romanc...
# 7                           Golden Mummy Golden Bird
# 8                                        Cosmic Love
# 9                                      Sehr kosmisch
#
#                            release  \
# 0                   Catch You Baby
# 1               If There Was A Way
# 2                  Vespertine Live
# 3                Only By The Night
# 4                    It's The Time
# 5                         Daughtry
# 6  Mozart - Eine kleine Nachtmusik
# 7                 Desperate Living
# 8                            Lungs
# 9               Musik von Harmonia
#
#                                          artist_name  \
# 0                                      Lonnie Gordon
# 1                                      Dwight Yoakam
# 2                                              Björk
# 3                                      Kings Of Leon
# 4                                         Ron Carter
# 5                           Daughtry featuring Slash
# 6  Barry Tuckwell/Academy of St Martin-in-the-Fie...
# 7                                     Horse The Band
# 8                             Florence + The Machine
# 9                                           Harmonia
#
#                                                 song
# 0  Catch You Baby (Steve Pitron & Max Sanna Radio...
# 1                     You're The One - Dwight Yoakam
# 2                                       Undo - Björk
# 3                            Revelry - Kings Of Leon
# 4                   I CAN'T GET STARTED - Ron Carter
# 5             What I Want - Daughtry featuring Slash
# 6  Horn Concerto No. 4 in E flat K495: II. Romanc...
# 7          Golden Mummy Golden Bird - Horse The Band
# 8               Cosmic Love - Florence + The Machine
# 9                           Sehr kosmisch - Harmonia

# %% [markdown]
# ### > Recommend Playlist for myself, I like *Daft Punk*, *John Mayer*, *Hot Chip* and *Coldplay*

# %%
user_recommend_johnny
# Out:
#               song_id     score                           title  \
# 0  SOFRQTD12A81C233C0  0.620261                   Sehr kosmisch
# 1  SOAXGDH12A8C13F8A1  0.550955  Dog Days Are Over (Radio Edit)
# 2  SONYKOW12AB01849C9  0.507492                         Secrets
# 3  SOBONKR12A58A7A7E0  0.485121                  You're The One
# 4  SOTWNDJ12A8C143984  0.410735                        Marry Me
# 5  SOSXLTC12AF72A7F54  0.382656                         Revelry
# 6  SOAUWYT12A81C206F1  0.373248                            Undo
# 7  SODJWHY12A8C142CCE  0.369476                Hey_ Soul Sister
# 8  SOWCKVR12A8C142411  0.345323                    Use Somebody
# 9  SOLFXKT12AB017E3E0  0.317481                       Fireflies
#
#                                  release             artist_name  \
# 0                     Musik von Harmonia                Harmonia
# 1       Now That's What I Call Music! 75  Florence + The Machine
# 2                              Waking Up             OneRepublic
# 3                     If There Was A Way           Dwight Yoakam
# 4                 Save Me_ San Francisco                   Train
# 5                      Only By The Night           Kings Of Leon
# 6                        Vespertine Live                   Björk
# 7                 Save Me_ San Francisco                   Train
# 8                           Use Somebody           Kings Of Leon
# 9  Karaoke Monthly Vol. 2 (January 2010)      Charttraxx Karaoke
#
#                                                 song
# 0                           Sehr kosmisch - Harmonia
# 1  Dog Days Are Over (Radio Edit) - Florence + Th...
# 2                              Secrets - OneRepublic
# 3                     You're The One - Dwight Yoakam
# 4                                   Marry Me - Train
# 5                            Revelry - Kings Of Leon
# 6                                       Undo - Björk
# 7                           Hey_ Soul Sister - Train
# 8                       Use Somebody - Kings Of Leon
# 9                     Fireflies - Charttraxx Karaoke

# %%
item_recommend_johnny
# Out:
#               song_id     score                   title  \
# 0  SOJLYEB12A6D4F9750  4.232522                   Angel
# 1  SOAWXHP12AB01840AC  2.949521                Lemonade
# 2  SOJZVDN12A8C133C0B  2.863139   With Oden On Our Side
# 3  SOKIYKH12AB0186B3C  2.750674  Please Read The Letter
# 4  SOACMJJ12A6D4FC66A  2.524626         Legacy Of Kings
# 5  SOMXKVF12AF72A9AA3  2.325515                    Fear
# 6  SOFESLM12AB017ED43  2.205051                 Play On
# 7  SOMFPCO12AF72ABFC2  2.181799       Falling Or Flying
# 8  SOUAWVS12A6D4F606C  2.127439        Spente Le Stelle
# 9  SOEEYKC12A6701DE4E  1.986232                In Cairo
#
#                                        release  \
# 0                      Beneath These Fireworks
# 1                                  Grey Oceans
# 2                        With Oden On Our Side
# 3                         2009 GRAMMY Nominees
# 4        Steel Meets Steel - 10 Years Of Glory
# 5                                    Waking Up
# 6                                      Play On
# 7  Grey's Anatomy Volume 3 Original Soundtrack
# 8                                  Carmine Meo
# 9                        Make Up The Breakdown
#
#                        artist_name  \
# 0                   Matt Nathanson
# 1                        Cocorosie
# 2                      Amon Amarth
# 3     Robert Plant & Alison Krauss
# 4                       HAMMERFALL
# 5                      OneRepublic
# 6                 Carrie Underwood
# 7  Grace Potter and the Nocturnals
# 8                    Emma Shapplin
# 9                     Hot Hot Heat
#
#                                                 song
# 0                             Angel - Matt Nathanson
# 1                               Lemonade - Cocorosie
# 2                With Oden On Our Side - Amon Amarth
# 3  Please Read The Letter - Robert Plant & Alison...
# 4                       Legacy Of Kings - HAMMERFALL
# 5                                 Fear - OneRepublic
# 6                         Play On - Carrie Underwood
# 7  Falling Or Flying - Grace Potter and the Noctu...
# 8                   Spente Le Stelle - Emma Shapplin
# 9                            In Cairo - Hot Hot Heat

# %%
latent_recommend_johnny
# Out:
#               song_id     score  \
# 0  SOHTKMO12AB01843B0  1.803866
# 1  SOBONKR12A58A7A7E0  0.964882
# 2  SOUFTBI12AB0183F65  0.907163
# 3  SOAUWYT12A81C206F1  0.851267
# 4  SOHKZSM12A8C13E5D5  0.695036
# 5  SOUNZHU12A8AE47481  0.566750
# 6  SOSXLTC12AF72A7F54  0.477508
# 7  SOWMDQL12A8C13FB54  0.469171
# 8  SOXWYZP12AF72A42A6  0.371683
# 9  SOZWBVE12AAF3B515C  0.364014
#
#                                                title  \
# 0  Catch You Baby (Steve Pitron & Max Sanna Radio...
# 1                                     You're The One
# 2                                            Invalid
# 3                                               Undo
# 4                     (They Long To Be) Close To You
# 5                                I CAN'T GET STARTED
# 6                                            Revelry
# 7                                        What I Want
# 8                                        Cosmic Love
# 9                           Golden Mummy Golden Bird
#
#                                 release               artist_name  \
# 0                        Catch You Baby             Lonnie Gordon
# 1                    If There Was A Way             Dwight Yoakam
# 2                         Fermi Paradox                  Tub Ring
# 3                       Vespertine Live                     Björk
# 4  The Essential Collection (1965-1997)                Carpenters
# 5                         It's The Time                Ron Carter
# 6                     Only By The Night             Kings Of Leon
# 7                              Daughtry  Daughtry featuring Slash
# 8                                 Lungs    Florence + The Machine
# 9                      Desperate Living            Horse The Band
#
#                                                 song
# 0  Catch You Baby (Steve Pitron & Max Sanna Radio...
# 1                     You're The One - Dwight Yoakam
# 2                                 Invalid - Tub Ring
# 3                                       Undo - Björk
# 4        (They Long To Be) Close To You - Carpenters
# 5                   I CAN'T GET STARTED - Ron Carter
# 6                            Revelry - Kings Of Leon
# 7             What I Want - Daughtry featuring Slash
# 8               Cosmic Love - Florence + The Machine
# 9          Golden Mummy Golden Bird - Horse The Band

# %% [markdown]
# We see that the all the recommended playlist are actually kind of make sense. In the following notebook, I will continue to try some other methods to build up custom recommended playlists.

# %% [markdown]
# ### Reference
#
# * http://nbviewer.jupyter.org/github/ethen8181/machine-learning/blob/master/recsys/1_ALSWR.ipynb
# * https://github.com/dvysardana/RecommenderSystems_PyData_2016/blob/master/Song%20Recommender_Python.ipynb
